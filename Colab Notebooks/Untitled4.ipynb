# %%
<?php
  $a = 1; // A variável $a é igual a 1
  $a += 2; // Somamos 2 ao valor da $a;
  echo $a;
?>
# Out:
#   File "<ipython-input-1-28e300689f9d>", line 1
#     <?php
#     ^
# SyntaxError: invalid syntax
