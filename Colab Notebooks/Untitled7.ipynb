# %%
N = int(input("insira o numero"))
i = 0
while i <= N:
  print(i)
  i = i+1
# Out:
# insira o numero5

# %%
cont = 0
soma = 0
while cont <= 12:
  soma += cont
  cont += 2
print(cont)
print(soma)
# Out:
# 14
# 42
