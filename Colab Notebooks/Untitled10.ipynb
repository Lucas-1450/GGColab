# %%
#Gerando lista com números aleatórios entre 0 e 100
import random
listanumeros = random.sample(range(100), 50)
print(listanumeros)
# Out:
# [70, 21, 36, 11, 20, 88, 57, 69, 3, 65, 2, 72, 49, 78, 8, 16, 85, 73, 55, 76, 19, 77, 61, 51, 13, 1, 24, 63, 79, 28, 34, 10, 46, 83, 14, 18, 9, 95, 5, 82, 62, 50, 81, 96, 27, 99, 66, 32, 44, 59]
