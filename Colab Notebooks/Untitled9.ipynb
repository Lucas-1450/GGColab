# %%
let txt = "";

function funcao(value, index, array) {
    if (index % 2 == 0) {text += value};
}

function xpto(x) {
    x.forEach(funcao)
    return txt;
}

alert (xpto([0,1,1,2,3,5]));
# Out:
#   File "<ipython-input-1-89fe874782a2>", line 1
#     let txt = "";
#           ^
# SyntaxError: invalid syntax
