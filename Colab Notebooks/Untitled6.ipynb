# %%
pip install pyautogui
# Out:
# ...
#      |████████████████████████████████| 59 kB 1.9 MB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 132 kB 15.6 MB/s
# ...
#   Created wheel for pyautogui: filename=PyAutoGUI-0.9.53-py3-none-any.whl size=36614 sha256=c1b2808eb13fc080e2f277ddecfda8faf383fdd07d5f82d64695b7a288ba79ca
#   Stored in directory: /root/.cache/pip/wheels/23/db/81/a14b5eca81ccb97c15e5bbea8d5394b8cbf6b36451d89dd648
# ...
#   Created wheel for pygetwindow: filename=PyGetWindow-0.0.9-py3-none-any.whl size=11078 sha256=8ab1c64f992cccd1ec1987a0b1be8ea1136cf11a68801d3c2877be5389aff387
#   Stored in directory: /root/.cache/pip/wheels/91/7e/35/62d9062a06cfc46fea39e26860253da36f258b3f3fd96c91c3
# ...

# %%
import pyautogui
import time
import pyperclip
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-4b0869233715> in <module>()
# ----> 1 import pyautogui
#       2 import time
#       3 import pyperclip
#
# /usr/local/lib/python3.7/dist-packages/pyautogui/__init__.py in <module>()
#     247
#     248 try:
# --> 249     import mouseinfo
#     250
#     251     def mouseInfo():
#
# /usr/local/lib/python3.7/dist-packages/mouseinfo/__init__.py in <module>()
#     221             raise
#     222
# --> 223     _display = Display(os.environ['DISPLAY'])
#     224
#     225     def _linuxPosition():
#
# /usr/lib/python3.7/os.py in __getitem__(self, key)
#     679         except KeyError:
#     680             # raise KeyError with the original key value
# --> 681             raise KeyError(key) from None
#     682         return self.decodevalue(value)
#     683
#
# KeyError: 'DISPLAY'
